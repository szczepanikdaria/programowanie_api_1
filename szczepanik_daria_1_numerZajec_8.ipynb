# %%
import pandas as pd

# %%
MAIN_DATA = pd.read_csv("/content/test.csv")

# %%
df_titanic = MAIN_DATA.copy()

# %%
df_titanic = df_titanic[["Name", "Age", "Sex"]]

# %%
df_titanic
# Out:
#                                              Name   Age     Sex
# 0                                Kelly, Mr. James  34.5    male
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0  female
# 2                       Myles, Mr. Thomas Francis  62.0    male
# 3                                Wirz, Mr. Albert  27.0    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0  female
# ..                                            ...   ...     ...
# 413                            Spector, Mr. Woolf   NaN    male
# 414                  Oliva y Ocana, Dona. Fermina  39.0  female
# 415                  Saether, Mr. Simon Sivertsen  38.5    male
# 416                           Ware, Mr. Frederick   NaN    male
# 417                      Peter, Master. Michael J   NaN    male
#
# [418 rows x 3 columns]

# %%
df_titanic.describe() #mediana to 50% wiec tu - 27
# Out:
#               Age
# count  332.000000
# mean    30.272590
# std     14.181209
# min      0.170000
# 25%     21.000000
# 50%     27.000000
# 75%     39.000000
# max     76.000000

# %%
df_titanic['Sex'] = df_titanic['Sex'].map({'male' : 0, 'female' : 1})

# %%
df_titanic.head()
# Out:
#                                            Name   Age  Sex
# 0                              Kelly, Mr. James  34.5    0
# 1              Wilkes, Mrs. James (Ellen Needs)  47.0    1
# 2                     Myles, Mr. Thomas Francis  62.0    0
# 3                              Wirz, Mr. Albert  27.0    0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0    1

# %%
men_count = (df_titanic['Sex'] == 0).sum()
women_count = (df_titanic['Sex'] == 1).sum()

# %%
print(f"Liczba mężczyzn: {men_count}")
print(f"Liczba kobiet: {women_count}")
# Out:
# Liczba mężczyzn: 266
# Liczba kobiet: 152

# %%
df_titanic['Year of birth'] = (1912 - df_titanic['Age']).round() #wiem, ze powinno byc zaokrąglone w dół, ale nie wiem jak inaczej niestety

# %%
df_titanic.head()
# Out:
#                                            Name   Age  Sex  Year of birth
# 0                              Kelly, Mr. James  34.5    0         1878.0
# 1              Wilkes, Mrs. James (Ellen Needs)  47.0    1         1865.0
# 2                     Myles, Mr. Thomas Francis  62.0    0         1850.0
# 3                              Wirz, Mr. Albert  27.0    0         1885.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0    1         1890.0
